# %% [markdown]
# # Flow Results Visualization
#
# Renders the flow comparison results table as a PNG image.
#
# | Input | Output |
# |-------|--------|
# | `results/flow_comparison_table.csv` | `graphics/flow_comparison_table.png` |

# %% [markdown]
# Import libraries for file operations, tabular data loading, and figure generation.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Define the path to the results CSV and the destination path for the output PNG.

# %%
DATA_PATH   = "../results/flow_comparison_table.csv"
OUTPUT_PATH = "../graphics/flow_comparison_table.png"

# %% [markdown]
# Load the results CSV and preview it as a DataFrame to confirm the data before plotting.

# %%
df = pd.read_csv(DATA_PATH)
df
# Out:
#         Experiment Model  CF 15cm (%)  CF 5cm (%)  CF 1cm (%)    RMSE     MAE  \
# 0         Baseline    LR        99.24       90.54       54.72  0.0386  0.0191
# 1         Baseline    RF        98.79       89.26       52.88  0.0428  0.0211
# 2         Baseline   MLP        99.82       93.64       62.26  0.0274  0.0149
# 3       All Inputs    LR        99.91       97.08       67.88  0.0187  0.0105
# 4       All Inputs    RF        99.08       90.98       57.90  0.0351  0.0181
# 5       All Inputs   MLP        96.59       80.60       48.91  0.0599  0.0312
# 6      GWL WL Flow    LR        98.92       89.21       44.02  0.0462  0.0229
# 7      GWL WL Flow    RF        98.91       89.73       53.66  0.0385  0.0199
# 8      GWL WL Flow   MLP        49.82       44.03       32.13  0.2326  0.1589
# 9         GWL Flow    LR        98.95       88.85       47.56  0.0463  0.0227
# 10        GWL Flow    RF        98.89       89.92       53.51  0.0375  0.0198
# 11        GWL Flow   MLP        95.54       77.25       45.75  0.0845  0.0391
# 12  GWL Rain Gates    LR        99.20       91.67       58.40  0.0371  0.0179
# 13  GWL Rain Gates    RF        98.96       89.59       52.82  0.0377  0.0200
# 14  GWL Rain Gates   MLP        49.81       44.00       38.04  0.2326  0.1580
#
#        R2
# 0   0.891
# 1   0.866
# 2   0.945
# 3   0.975
# 4   0.910
# 5   0.738
# 6   0.844
# 7   0.892
# 8  -2.949
# 9   0.843
# 10  0.897
# 11  0.478
# 12  0.900
# 13  0.896
# 14 -2.948

# %% [markdown]
# Render the DataFrame as a matplotlib table on a blank axis, apply font and scale styling, then save the figure to the `graphics/` folder (creating it if needed) and display it inline.

# %%
fig, ax = plt.subplots(figsize=(10, 4))
ax.axis("off")

table = ax.table(
    cellText=df.values,
    colLabels=df.columns,
    cellLoc="center",
    loc="center",
)
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

os.makedirs(os.path.dirname(OUTPUT_PATH), exist_ok=True)
plt.savefig(OUTPUT_PATH, bbox_inches="tight", dpi=300)
print(f"Saved \u2192 {OUTPUT_PATH}")
plt.show()
# Out:
# Saved → ../graphics/flow_comparison_table.png
